# %% [markdown]
# # 00 - Data exploration
#
# This notebook is part of the {{ cookiecutter.project_name }} project.
# It is intended for initial data inspection and exploratory analysis.

# %%
from pathlib import Path

import pandas as pd

from {{ cookiecutter.package_name }}.utils.io import load_csv

DATA_PATH = Path("../data/processed/train.csv")

if not DATA_PATH.exists():
    raise FileNotFoundError(f"Expected dataset at {DATA_PATH}.")

df = load_csv(DATA_PATH)
df.head()

# %%
df.info()

# %%
df.describe(include="all").T
